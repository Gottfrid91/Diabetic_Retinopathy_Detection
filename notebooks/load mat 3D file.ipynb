# %%
import scipy.io as scp
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
data_dir = '/home/olle/PycharmProjects/Diabetic_Retinopathy_Detection/data/OCT_drd_images/sample/'

# %%
data = scp.loadmat(data_dir + "1p.mat")
img = data['d5'].astype(float)
print(img.shape)
imgplot = plt.imshow(img[:,:,3])
# Out:
# (650, 512, 128)
